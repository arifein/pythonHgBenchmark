# %%
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import numpy as np
import pandas as pd
import xbpch
import cartopy.crs as ccrs
from matplotlib import colorbar, colors
import statistics
from sklearn.metrics import r2_score
# %matplotlib inline

from GeneralGraph import GeneralHgMeanSurface
from MeanSurfaceTGM import HgMeanSurfaceTGM
from PlotSeasonSites import PlotSeasonSites
from TGMAndObs import SurfaceObsTGM

# %%
from GeneralGraph import GeneralHgMeanSurface
from MeanSurfaceTGM import HgMeanSurfaceTGM
from PlotSeasonSites import PlotSeasonSites
from TGMAndObs import SurfaceObsTGM

# %%
# Name the xbpch files for the reference and new models
OLD = '/home/brittany/Documents/HG/pythonHgBenchmark/trac_avg.geosfp_2x25_Hg.v12-01.bpch'
NEW = '/home/brittany/Documents/HG/pythonHgBenchmark/trac_avg.geosfp_2x25_Hg.v12-01.new.bpch'



# Upload/open the data from the models 
OLD_ds = (xbpch.open_bpchdataset(OLD))
NEW_ds = (xbpch.open_bpchdataset(NEW))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-83dd62bfa63f> in <module>
#       6
#       7 # Upload/open the data from the models
# ----> 8 OLD_ds = (xbpch.open_bpchdataset(OLD))
#       9 NEW_ds = (xbpch.open_bpchdataset(NEW))
#
# ~/anaconda3/envs/geoschem/lib/python3.6/site-packages/xbpch/core.py in open_bpchdataset(filename, fields, categories, tracerinfo_file, diaginfo_file, endian, decode_cf, memmap, dask, return_store)
#      78         tracerinfo_file=tracerinfo_file,
#      79         diaginfo_file=diaginfo_file, endian=endian,
# ---> 80         use_mmap=memmap, dask_delayed=dask
#      81     )
#      82     ds = xr.Dataset.load_store(store)
#
# ~/anaconda3/envs/geoschem/lib/python3.6/site-packages/xbpch/core.py in __init__(self, filename, fields, categories, fix_cf, mode, endian, diaginfo_file, tracerinfo_file, use_mmap, dask_delayed)
#     250
#     251         self.filename = filename
# --> 252         self.fsize = os.path.getsize(self.filename)
#     253         self.mode = mode
#     254         if not mode.startswith('r'):
#
# ~/anaconda3/envs/geoschem/lib/python3.6/genericpath.py in getsize(filename)
#      48 def getsize(filename):
#      49     """Return the size of a file, reported by os.stat()."""
# ---> 50     return os.stat(filename).st_size
#      51
#      52
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/brittany/Documents/HG/pythonHgBenchmark/trac_avg.geosfp_2x25_Hg.v12-01.bpch'

# %%
PlotSeasonSites(OLD_ds, NEW_ds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8e4761cbe61b> in <module>
# ----> 1 PlotSeasonSites(OLD_ds, NEW_ds)
#
# NameError: name 'OLD_ds' is not defined

# %%
SurfaceObsTGM(OLD_ds, NEW_ds)
# Out:
# /home/brittany/anaconda3/envs/geoschem/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# (<Figure size 432x288 with 2 Axes>, <Figure size 432x288 with 2 Axes>)

# %%
HgMeanSurfaceTGM(Dataset_OLD=OLD_ds,Dataset_NEW= NEW_ds)
# Out:
# /home/brittany/anaconda3/envs/geoschem/lib/python3.6/site-packages/matplotlib/contour.py:1004: UserWarning: The following kwargs were not used by contour: 'title'
#   s)

# %%
GeneralHgMeanSurface(Dataset_OLD=OLD_ds,Dataset_NEW= NEW_ds,  Variable=['IJ_AVG_S_Hg0', 'IJ_AVG_S_Hg2'], 
                      Units="$ng/m^2$", Unit_Conversion=8.93, Title="Surface TGM")
